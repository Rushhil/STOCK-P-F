# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
pd.set_option("display.max_columns", None) 
pd.set_option('display.max_colwidth', None) 
pd.set_option("display.expand_frame_repr", False)

# %%
astock = pd.read_csv("F:\Amazon Stock\AMZN.csv")

# %%
display(astock)
# Out:
#            Date        Open        High         Low       Close   Adj Close     Volume
# 0    2012-05-14   11.252500   11.300000   10.640500   10.692500   10.692500  194744000
# 1    2012-05-21   10.701500   10.999000   10.559000   10.644500   10.644500  337384000
# 2    2012-05-28   10.715000   10.827500   10.355500   10.411000   10.411000  313352000
# 3    2012-06-04   10.370000   11.074500   10.318500   10.924000   10.924000  338690000
# 4    2012-06-11   10.874500   11.043500   10.628000   10.917500   10.917500  315074000
# ..          ...         ...         ...         ...         ...         ...        ...
# 524  2022-05-30  116.279999  125.610001  115.675003  122.349998  122.349998  470326000
# 525  2022-06-06  125.250000  128.990005  109.050003  109.650002  109.650002  439648100
# 526  2022-06-13  104.190002  109.059998  101.430000  106.220001  106.220001  435602900
# 527  2022-06-20  108.199997  116.709999  103.559998  116.459999  116.459999  265079600
# ...

# %%
astock.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close     Volume
# 0  2012-05-14  11.2525  11.3000  10.6405  10.6925    10.6925  194744000
# 1  2012-05-21  10.7015  10.9990  10.5590  10.6445    10.6445  337384000
# 2  2012-05-28  10.7150  10.8275  10.3555  10.4110    10.4110  313352000
# 3  2012-06-04  10.3700  11.0745  10.3185  10.9240    10.9240  338690000
# 4  2012-06-11  10.8745  11.0435  10.6280  10.9175    10.9175  315074000

# %%
astock.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close     Volume
# 524  2022-05-30  116.279999  125.610001  115.675003  122.349998  122.349998  470326000
# 525  2022-06-06  125.250000  128.990005  109.050003  109.650002  109.650002  439648100
# 526  2022-06-13  104.190002  109.059998  101.430000  106.220001  106.220001  435602900
# 527  2022-06-20  108.199997  116.709999  103.559998  116.459999  116.459999  265079600
# 528  2022-06-24  112.379997  116.709999  111.430000  116.459999  116.459999   69728118

# %%
astock2=astock.reset_index()['Close']

# %%
astock2.shape
# Out:
# (529,)

# %%
astock.isna().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
astock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       529 non-null    object
#  1   Open       529 non-null    float64
#  2   High       529 non-null    float64
#  3   Low        529 non-null    float64
#  4   Close      529 non-null    float64
#  5   Adj Close  529 non-null    float64
#  6   Volume     529 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 29.1+ KB

# %%
astock['Close'].plot(figsize=(18,6))
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0, 1))
astock2=scaler.fit_transform(np.array(astock2).reshape(-1,1))

# %%
pd.set_option('display.max_colwidth', None)

# %%
astock2
# Out:
# array([[0.00160348],
#        [0.00133006],
#        [0.        ],
#        [0.00292214],
#        [0.00288512],
#        [0.00397024],
#        [0.00573321],
#        [0.00479334],
#        [0.00289651],
#        [0.00571612],
#        [0.00828795],
#        [0.00761865],
#        [0.00698637],
#        [0.00938447],
#        [0.01068605],
#        [0.01140662],
#        [0.0145025 ],
#        [0.01510914],
#        [0.01402686],
#        [0.01312971],
#        [0.01432307],
#        [0.00972339],
#        [0.00905124],
#        [0.00854998],
#        [0.00689239],
#        [0.0051522 ],
#        [0.00484461],
#        [0.00901707],
#        [0.0124832 ],
#        [0.01283066],
#        [0.01166864],
#        [0.01387022],
#        [0.01052656],
#        [0.01450534],
#        [0.01700882],
#        [0.01819932],
#        [0.02158001],
#        [0.01617148],
#        [0.01530281],
#        [0.01619711],
#        [0.0162911 ],
#        [0.01638224],
#        [0.01878888],
# ...

# %%
##splitting dataset into train and test split
training_size=int(len(astock2)*0.65)
test_size=len(astock2)-training_size
train_data,test_data=astock2[0:training_size,:],astock2[training_size:len(astock2),:1]

# %%
training_size,test_size
# Out:
# (343, 186)

# %%
len(train_data)
# Out:
# 343

# %%
train_data
# Out:
# array([[0.00160348],
#        [0.00133006],
#        [0.        ],
#        [0.00292214],
#        [0.00288512],
#        [0.00397024],
#        [0.00573321],
#        [0.00479334],
#        [0.00289651],
#        [0.00571612],
#        [0.00828795],
#        [0.00761865],
#        [0.00698637],
#        [0.00938447],
#        [0.01068605],
#        [0.01140662],
#        [0.0145025 ],
#        [0.01510914],
#        [0.01402686],
#        [0.01312971],
#        [0.01432307],
#        [0.00972339],
#        [0.00905124],
#        [0.00854998],
#        [0.00689239],
#        [0.0051522 ],
#        [0.00484461],
#        [0.00901707],
#        [0.0124832 ],
#        [0.01283066],
#        [0.01166864],
#        [0.01387022],
#        [0.01052656],
#        [0.01450534],
#        [0.01700882],
#        [0.01819932],
#        [0.02158001],
#        [0.01617148],
#        [0.01530281],
#        [0.01619711],
#        [0.0162911 ],
#        [0.01638224],
#        [0.01878888],
# ...

# %%
# convert an array of values into a dataset matrix
import numpy 
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]  
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train)
# Out:
# [[0.00160348 0.00133006 0.         ... 0.03704515 0.03269042 0.02948062]
#  [0.00133006 0.         0.00292214 ... 0.03269042 0.02948062 0.03323442]
#  [0.         0.00292214 0.00288512 ... 0.02948062 0.03323442 0.02723063]
#  ...
#  [0.15651701 0.15732017 0.15426702 ... 0.40858475 0.41505559 0.42841316]
#  [0.15732017 0.15426702 0.16740243 ... 0.41505559 0.42841316 0.39451516]
#  [0.15426702 0.16740243 0.17342614 ... 0.42841316 0.39451516 0.36849779]]

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (242, 100)
# (242,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (85, 100)
# (85,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 10s 411ms/step - loss: 0.0318 - val_loss: 0.1174
# Epoch 2/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0084 - val_loss: 0.0159
# Epoch 3/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0047 - val_loss: 0.0987
# Epoch 4/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0051 - val_loss: 0.0302
# Epoch 5/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0016 - val_loss: 0.0330
# Epoch 6/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0017 - val_loss: 0.0172
# Epoch 7/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0012 - val_loss: 0.0114
# Epoch 8/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0013 - val_loss: 0.0364
# Epoch 9/100
# 4/4 [==============================] - 0s 53ms/step - loss: 9.6000e-04 - val_loss: 0.0152
# Epoch 10/100
# ...

# %%
import tensorflow as tf

# %%
# Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# ...
# 3/3 [==============================] - 0s 18ms/step

# %%
#Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
# Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 48.455855009369216

# %%
# Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 93.00006993400946

# %%
look_back=100
trainPredictPlot = numpy.empty_like(astock2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
testPredictPlot = numpy.empty_like(astock2)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(astock2)-1, :] = test_predict
plt.plot(scaler.inverse_transform(astock2))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 186

# %%
x_input=test_data[86:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.8428194149678568,
#  0.8372827199663561,
#  0.8762161155476349,
#  0.9095616244834022,
#  0.8790357914009145,
#  0.8282258033968023,
#  0.7822831627025896,
#  0.8222191443818253,
#  0.8307264015677733,
#  0.876765866070253,
#  0.8727955886667386,
#  0.853340274708363,
#  0.8054210566833676,
#  0.8838063149025472,
#  0.8318115596109379,
#  0.8234352862743309,
#  0.8507598843320617,
#  0.8414295279406436,
#  0.8282827311024041,
#  0.8525570659093699,
#  0.8443089966822266,
#  0.8683012904230357,
#  0.8471598762548668,
#  0.8248165720572516,
#  0.8783550570289553,
#  0.8538529145643816,
#  0.8954208484876862,
#  0.8742196357350258,
#  0.8662990688526473,
#  0.8215925636717789,
#  0.7952562087099333,
#  0.8206128363773622,
#  0.8164745442045428,
#  0.8099438643493776,
#  0.8409795575480064,
#  0.901131294320083,
#  0.9088894970519236,
#  0.8922110919652729,
#  0.9282508523847335,
#  0.8781785264581822,
#  0.8586092659495906,
#  0.8529643604594649,
#  0.8586576778537242,
# ...

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.3110746]
# 101
# 1 day input [0.83728272 0.87621612 0.90956162 0.87903579 0.8282258  0.78228316
#  0.82221914 0.8307264  0.87676587 0.87279559 0.85334027 0.80542106
#  0.88380631 0.83181156 0.82343529 0.85075988 0.84142953 0.82828273
#  0.85255707 0.844309   0.86830129 0.84715988 0.82481657 0.87835506
#  0.85385291 0.89542085 0.87421964 0.86629907 0.82159256 0.79525621
#  0.82061284 0.81647454 0.80994386 0.84097956 0.90113129 0.9088895
#  0.89221109 0.92825085 0.87817853 0.85860927 0.85296436 0.85865768
#  0.85385865 0.89390571 0.93379893 0.9094648  0.94065712 1.
#  0.95850047 0.98214248 0.88842595 0.89336735 0.87885066 0.85207286
#  0.89470317 0.93127834 0.92874358 0.92685531 0.91631733 0.87580031
#  0.87732692 0.91161799 0.890693   0.90119683 0.94293842 0.94469293
#  0.98781876 0.93882865 0.9061411  0.92164899 0.90914869 0.91513535
#  0.89034838 0.86663518 0.86426556 0.7532184  0.76082276 0.83864123
#  0.81388564 0.80994386 0.81670522 0.77029557 0.76963197 0.85921021
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(astock2)
# Out:
# 529

# %%
astock3=astock2.tolist()
astock3.extend(lst_output)

# %%
plt.plot(day_new,scaler.inverse_transform(astock2[429:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
astock3=astock2.tolist()
astock3.extend(lst_output)
plt.plot(astock3[500:])

# %%
astock3=scaler.inverse_transform(astock3).tolist()

# %%
plt.plot(astock3)
